# %% [markdown]
# # Welcome to numpy tutorial

# %% [markdown]
# **this**

# %% [markdown]
# _this_

# %% [markdown]
# *this*

# %% [markdown]
# ***this***

# %%
import numpy as np

# %%
myarr=np.array([3,6,32,7],np.int64)

# %%
myarr
# Out:
# array([ 3,  6, 32,  7])

# %%
myarro=np.array([[1,2,3,4]],np.int64)

# %%
myarro
# Out:
# array([[1, 2, 3, 4]])

# %%
myarr[0,1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 myarr[0,1]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
myarro[0,1]

# %%
myarr[0]

# %%
myarr.shape

# %%
myarro.shape

# %%
myarr.dtype

# %%
myarr[0]=56

# %%
myarr

# %% [markdown]
# **Array creation type-1 : Conversion from other python structures**

# %%
listarr=np.array([[1,2,3],[4,5,6]])

# %%
listarr

# %%
listarr.shape

# %%
listarr.dtype

# %%
listarr.size

# %%
listarr[2][1]=68

# %%
listarr[1,1]=56

# %%
listarr

# %%
np.array({1,2,3})

# %% [markdown]
# ***type2: INtrinsic***

# %%
zeros=np.zeros((2,5))

# %%
zeros

# %%
zeros.dtype

# %%
zeros.shape

# %%
zeros.size

# %%
range=np.arange(2,50)

# %%
range

# %%
linspace=np.linspace(1,50,10)

# %%
linspace

# %%
emp=np.empty((4,6))

# %%
emp

# %%
emp_like=np.empty_like(linspace)

# %%
emp_like

# %%
ide=np.identity(4) #gives identity matrix

# %%
ide

# %%
ide.shape

# %% [markdown]
# **functions**

# %%
arr=np.arange(99)

# %%
arr

# %%
#to reshapepe

# %%
arr.reshape(9,11)

# %%
arr.reshape(3,33)

# %%
arr.ravel() #to remove the reshaping

# %%
arr.shape

# %%
  #axis o refers to col wise
#axis1 refers to row wise

# %%
x=[[1,2,3],[4,5,6],[7,8,9]]

# %% [raw]
# a=np.array(x)

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
S
